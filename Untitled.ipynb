# %%
# !python generate_graph27.py
# Out:
# 2024-07-09 16:26:00,734 - INFO - Starting data processing.
# 2024-07-09 16:26:00,734 - INFO - Loading graph structure from Graphs/Graph36/graph_structure.yaml
# 2024-07-09 16:26:00,740 - INFO - Graph structure loaded successfully.
# 2024-07-09 16:26:00,740 - INFO - Row counts calculated: {'train': 64000, 'val': 16000, 'test': 20000}
# 2024-07-09 16:26:00,740 - INFO - Processing train data from CSVs/train_data.csv with 64000 rows.
# 2024-07-09 16:26:01,161 - INFO - Processing chunk 1 for train data.
# 2024-07-09 16:26:01,455 - INFO - Processed 1000 rows for train data.
# 2024-07-09 16:26:01,745 - INFO - Processed 2000 rows for train data.
# 2024-07-09 16:26:02,035 - INFO - Processed 3000 rows for train data.
# 2024-07-09 16:26:02,325 - INFO - Processed 4000 rows for train data.
# 2024-07-09 16:26:02,614 - INFO - Processed 5000 rows for train data.
# 2024-07-09 16:26:02,904 - INFO - Processed 6000 rows for train data.
# ...

# %%
# !python gnn_training27.py
# Out:
# 2024-07-07 01:20:08,473 - INFO - Epoch 1, Train Loss: 22.4885, Val Loss: 10.9105, Train Acc: 0.2809, Val Acc: 0.3063
# 2024-07-07 01:20:22,428 - INFO - Epoch 2, Train Loss: 2.2886, Val Loss: 1.4005, Train Acc: 0.3495, Val Acc: 0.3513
# 2024-07-07 01:20:36,359 - INFO - Epoch 3, Train Loss: 1.3706, Val Loss: 1.3900, Train Acc: 0.3616, Val Acc: 0.3513
# 2024-07-07 01:20:50,259 - INFO - Epoch 4, Train Loss: 1.3661, Val Loss: 1.3882, Train Acc: 0.3616, Val Acc: 0.3513
# 2024-07-07 01:21:04,075 - INFO - Epoch 5, Train Loss: 1.3641, Val Loss: 1.3866, Train Acc: 0.3616, Val Acc: 0.3513
# 2024-07-07 01:21:17,866 - INFO - Epoch 6, Train Loss: 1.3633, Val Loss: 1.3860, Train Acc: 0.3616, Val Acc: 0.3513
# 2024-07-07 01:21:31,820 - INFO - Epoch 7, Train Loss: 1.3621, Val Loss: 1.3844, Train Acc: 0.3616, Val Acc: 0.3513
# 2024-07-07 01:21:45,713 - INFO - Epoch 8, Train Loss: 1.3621, Val Loss: 1.3850, Train Acc: 0.3616, Val Acc: 0.3513
# ...

# %%
# !python gnn_training28.py
# Out:
# 2024-07-07 01:49:16,410 - INFO - Epoch 1, Train Loss: 16.2504, Val Loss: 6.3259, Train Acc: 0.3178, Val Acc: 0.3050
# 2024-07-07 01:49:29,255 - INFO - Epoch 2, Train Loss: 1.5409, Val Loss: 1.3913, Train Acc: 0.3575, Val Acc: 0.3513
# 2024-07-07 01:49:42,513 - INFO - Epoch 3, Train Loss: 1.3635, Val Loss: 1.3873, Train Acc: 0.3616, Val Acc: 0.3513
# 2024-07-07 01:49:55,700 - INFO - Epoch 4, Train Loss: 1.3625, Val Loss: 1.3870, Train Acc: 0.3616, Val Acc: 0.3513
# 2024-07-07 01:50:09,128 - INFO - Epoch 5, Train Loss: 1.3619, Val Loss: 1.3830, Train Acc: 0.3616, Val Acc: 0.3513
# 2024-07-07 01:50:22,047 - INFO - Epoch 6, Train Loss: 1.3619, Val Loss: 1.3909, Train Acc: 0.3616, Val Acc: 0.3513
# 2024-07-07 01:50:34,892 - INFO - Epoch 7, Train Loss: 1.3615, Val Loss: 1.3890, Train Acc: 0.3616, Val Acc: 0.3513
requires numpy>=1.24.4, but you have numpy 1.23.5 which is incompatible.
# roboflow 1.1.27 requires opencv-python-headless==4.8.0.74, but you have opencv-python-headless 4.9.0.80 which is incompatible.
# ...

# %%
# !pip show shap
# Out:
# Name: shap
# Version: 0.46.0
# Summary: A unified approach to explain the output of any machine learning model.
# Home-page:
# Author:
# Author-email: Scott Lundberg <slund1@cs.washington.edu>
# License: MIT License
# Location: /work/LAS/jannesar-lab/.ondemand/msharif/jupyter-envs/20230427/lib/python3.10/site-packages
# Requires: cloudpickle, numba, numpy, packaging, pandas, scikit-learn, scipy, slicer, tqdm
# Required-by:

# %%
# !python gnn_training39.py

# %%
# !python generate_graph41.py
# Out:
# 2024-07-22 18:09:10,110 - INFO - Starting data processing.
# 2024-07-22 18:09:10,110 - INFO - Loading graph structure from Graphs/Graph40/graph_structure.yaml
# 2024-07-22 18:09:10,116 - INFO - Graph structure loaded successfully.
# 2024-07-22 18:09:10,116 - INFO - Loading dataset from CSVs/sample_train.csv
# 2024-07-22 18:09:56,944 - INFO - Splitting dataset into training and testing sets with test size = 0.5
# 2024-07-22 18:10:01,510 - INFO - Processing training data with 3323609 rows.
# 2024-07-22 18:10:02,493 - INFO - All graphs saved to Graphs/Graph41/train_graphs.csv.
# 2024-07-22 18:10:02,501 - INFO - Processing testing data with 3323610 rows.
# 2024-07-22 18:10:03,522 - INFO - All graphs saved to Graphs/Graph41/test_graphs.csv.
# 2024-07-22 18:10:03,539 - INFO - Data processing completed.

# %%
# !python gnn_training41.py
# Out:
# /work/LAS/jannesar-lab/.ondemand/msharif/jupyter-envs/20230427/lib/python3.10/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# 2024-07-22 19:17:53,612 - INFO - Epoch 1, Train Loss: 96.2218, Test RMSE: 1.1879
# /work/LAS/jannesar-lab/.ondemand/msharif/jupyter-envs/20230427/lib/python3.10/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# 2024-07-22 19:17:54,659 - INFO - Epoch 2, Train Loss: 72.7523, Test RMSE: 1.2190
# ...

# %%
# !python generate_graph42.py
# Out:
# 2024-07-22 19:26:27,908 - INFO - Starting data processing.
# 2024-07-22 19:26:27,908 - INFO - Loading graph structure from Graphs/Graph42/graph_structure.yaml
# 2024-07-22 19:26:27,917 - INFO - Graph structure loaded successfully.
# 2024-07-22 19:26:27,917 - INFO - Loading dataset from CSVs/sample_train.csv
# 2024-07-22 19:27:15,680 - INFO - Splitting dataset into training and testing sets with test size = 0.5
# 2024-07-22 19:27:20,285 - INFO - Processing training data with 3323609 rows.
# 2024-07-22 19:27:25,609 - INFO - All graphs saved to Graphs/Graph42/train_graphs.csv.
# 2024-07-22 19:27:25,665 - INFO - Processing testing data with 3323610 rows.
# 2024-07-22 19:27:30,969 - INFO - All graphs saved to Graphs/Graph42/test_graphs.csv.
# 2024-07-22 19:27:31,033 - INFO - Data processing completed.

# %%
# !python gnn_training42.py
# Out:
# /work/LAS/jannesar-lab/.ondemand/msharif/jupyter-envs/20230427/lib/python3.10/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /work/LAS/jannesar-lab/.ondemand/msharif/jupyter-envs/20230427/lib/python3.10/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# 2024-07-22 19:30:13,139 - INFO - Epoch 1, Train Loss: 29.4401, Train RMSE: 1.1919, Test RMSE: 1.1816, Train Acc: 0.3390, Test Acc: 0.3470
# ...

# %%
# !python gnn_training43.py
# Out:
# 2024-07-22 22:29:34,469 - INFO - Loaded checkpoint from Graphs/Graph43/checkpoint.pt, starting at epoch 63
# 2024-07-22 22:30:31,368 - INFO - Epoch 63, Train Loss: 1.2087, Train RMSE: 0.9424, Test RMSE: 0.9338, Train Acc: 0.5048, Test Acc: 0.5083
# 2024-07-22 22:31:28,310 - INFO - Epoch 64, Train Loss: 1.2050, Train RMSE: 0.9383, Test RMSE: 0.9304, Train Acc: 0.5073, Test Acc: 0.5107
# 2024-07-22 22:32:25,429 - INFO - Epoch 65, Train Loss: 1.2040, Train RMSE: 0.9152, Test RMSE: 0.9086, Train Acc: 0.5153, Test Acc: 0.5217
# 2024-07-22 22:33:22,441 - INFO - Epoch 66, Train Loss: 1.2020, Train RMSE: 0.9348, Test RMSE: 0.9235, Train Acc: 0.5120, Test Acc: 0.5180
# 2024-07-22 22:34:19,337 - INFO - Epoch 67, Train Loss: 1.2004, Train RMSE: 0.9570, Test RMSE: 0.9508, Train Acc: 0.4999, Test Acc: 0.5057
# 2024-07-22 22:35:16,431 - INFO - Epoch 68, Train Loss: 1.2031, Train RMSE: 0.9357, Test RMSE: 0.9294, Train Acc: 0.5124, Test Acc: 0.5147
# ...

# %%
# !python gnn_training43.py
# Out:
# 2024-07-23 00:21:36,387 - INFO - Loaded checkpoint from Graphs/Graph43/checkpoint.pt, starting at epoch 176
# 2024-07-23 00:22:54,402 - INFO - Epoch 176, Train Loss: 1.1870, Train RMSE: 0.9406, Test RMSE: 0.9321, Train Acc: 0.5097, Test Acc: 0.5159
# 2024-07-23 00:24:12,136 - INFO - Epoch 177, Train Loss: 1.1865, Train RMSE: 0.9404, Test RMSE: 0.9321, Train Acc: 0.5098, Test Acc: 0.5156
# 2024-07-23 00:25:30,358 - INFO - Epoch 178, Train Loss: 1.1901, Train RMSE: 0.9385, Test RMSE: 0.9281, Train Acc: 0.5111, Test Acc: 0.5186
# 2024-07-23 00:26:48,058 - INFO - Epoch 179, Train Loss: 1.1881, Train RMSE: 0.9438, Test RMSE: 0.9345, Train Acc: 0.5063, Test Acc: 0.5145
# 2024-07-23 00:28:06,117 - INFO - Epoch 180, Train Loss: 1.1850, Train RMSE: 0.9410, Test RMSE: 0.9326, Train Acc: 0.5091, Test Acc: 0.5157
# 2024-07-23 00:29:23,840 - INFO - Epoch 181, Train Loss: 1.1861, Train RMSE: 0.9403, Test RMSE: 0.9310, Train Acc: 0.5098, Test Acc: 0.5160
# ...

# %%
# !python gnn_training43.py
# Out:
# 2024-07-23 03:54:09,355 - INFO - Loaded checkpoint from Graphs/Graph43/checkpoint.pt, starting at epoch 315
# 2024-07-23 03:55:24,952 - INFO - Epoch 315, Train Loss: 1.1846, Train RMSE: 0.9399, Test RMSE: 0.9307, Train Acc: 0.5099, Test Acc: 0.5159
# 2024-07-23 03:56:41,045 - INFO - Epoch 316, Train Loss: 1.1857, Train RMSE: 0.9397, Test RMSE: 0.9306, Train Acc: 0.5102, Test Acc: 0.5159
# 2024-07-23 03:57:56,387 - INFO - Epoch 317, Train Loss: 1.1870, Train RMSE: 0.9399, Test RMSE: 0.9303, Train Acc: 0.5098, Test Acc: 0.5158
# 2024-07-23 03:59:13,085 - INFO - Epoch 318, Train Loss: 1.1841, Train RMSE: 0.9397, Test RMSE: 0.9306, Train Acc: 0.5102, Test Acc: 0.5159
# 2024-07-23 04:00:29,089 - INFO - Epoch 319, Train Loss: 1.1859, Train RMSE: 0.9397, Test RMSE: 0.9301, Train Acc: 0.5100, Test Acc: 0.5159
# 2024-07-23 04:01:45,033 - INFO - Epoch 320, Train Loss: 1.1857, Train RMSE: 0.9397, Test RMSE: 0.9301, Train Acc: 0.5100, Test Acc: 0.5159

# %%
# !python gnn_training45.py
