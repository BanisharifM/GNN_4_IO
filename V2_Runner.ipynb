# %%
# total_rows = 1,000
# Graph200
# !source ~/env4/bin/activate && python /u/mbanisharifdehkordi/Github/GNN_4_IO/generate_graph100.py
# Out:
# 2024-09-29 22:21:07,482 - INFO - Starting data processing.
# 2024-09-29 22:21:07,482 - INFO - Loading graph structure from Graphs/Graph200/graph_structure.yaml
# 2024-09-29 22:21:07,509 - INFO - Graph structure loaded successfully.
# 2024-09-29 22:21:07,509 - INFO - Loading dataset from CSVs/sample_train.csv
# 2024-09-29 22:21:11,476 - INFO - Dataset loaded successfully.
# 2024-09-29 22:21:11,476 - INFO - Splitting dataset into training and testing sets with test size = 0.25
# 2024-09-29 22:21:11,736 - INFO - Dataset split into 786431 training rows and 262144 testing rows.
# 2024-09-29 22:21:11,736 - INFO - Processing training data with 786431 rows.
# 2024-09-29 22:21:13,158 - INFO - All graphs saved to Graphs/Graph200/train_graphs.csv.
# 2024-09-29 22:21:13,178 - INFO - Processing testing data with 262144 rows.
# 2024-09-29 22:21:14,564 - INFO - All graphs saved to Graphs/Graph200/test_graphs.csv.
# 2024-09-29 22:21:14,586 - INFO - Data processing completed.

# %%
# !source ~/env4/bin/activate && python /u/mbanisharifdehkordi/Github/GNN_4_IO/gnn_training200.py
# Out:
# 2024-09-29 22:30:46,055 - INFO - Epoch 1, Train Loss: 5.4466, Train RMSE: 4.6825, Test RMSE: 4.6839, Train MAE: 4.6818, Test MAE: 4.6835, Train R²: -9686.9515, Test R²: 0.0000
# 2024-09-29 22:30:47,219 - INFO - Epoch 2, Train Loss: 2.9778, Train RMSE: 0.4238, Test RMSE: 0.4248, Train MAE: 0.3422, Test MAE: 0.3529, Train R²: -78.3526, Test R²: 0.0000
# 2024-09-29 22:30:48,454 - INFO - Epoch 3, Train Loss: 0.5967, Train RMSE: 0.6957, Test RMSE: 0.7011, Train MAE: 0.6528, Test MAE: 0.6637, Train R²: -212.8335, Test R²: 0.0000
# 2024-09-29 22:30:49,619 - INFO - Epoch 4, Train Loss: 0.2716, Train RMSE: 0.4271, Test RMSE: 0.4281, Train MAE: 0.3488, Test MAE: 0.3593, Train R²: -79.6064, Test R²: 0.0000
# 2024-09-29 22:30:50,842 - INFO - Epoch 5, Train Loss: 0.1874, Train RMSE: 0.2788, Test RMSE: 0.2700, Train MAE: 0.1343, Test MAE: 0.1425, Train R²: -33.3411, Test R²: 0.0000
# ...

# %%
# total_rows = 10,000
# Graph200
# sample_train_total.csv
# !source ~/env4/bin/activate && python /u/mbanisharifdehkordi/Github/GNN_4_IO/generate_graph100.py
# Out:
# 2024-09-29 22:36:12,806 - INFO - Starting data processing.
# 2024-09-29 22:36:12,806 - INFO - Loading graph structure from Graphs/Graph200/graph_structure.yaml
# 2024-09-29 22:36:12,834 - INFO - Graph structure loaded successfully.
# 2024-09-29 22:36:12,834 - INFO - Loading dataset from CSVs/sample_train_total.csv
# 2024-09-29 22:36:46,218 - INFO - Dataset loaded successfully.
# 2024-09-29 22:36:46,219 - INFO - Splitting dataset into training and testing sets with test size = 0.25
# 2024-09-29 22:36:48,492 - INFO - Dataset split into 4985414 training rows and 1661805 testing rows.
# 2024-09-29 22:36:48,492 - INFO - Processing training data with 4985414 rows.
# 2024-09-29 22:37:03,175 - INFO - All graphs saved to Graphs/Graph200/train_graphs.csv.
# 2024-09-29 22:37:03,384 - INFO - Processing testing data with 1661805 rows.
# 2024-09-29 22:37:17,923 - INFO - All graphs saved to Graphs/Graph200/test_graphs.csv.
# 2024-09-29 22:37:18,139 - INFO - Data processing completed.

# %%
# !source ~/env4/bin/activate && python /u/mbanisharifdehkordi/Github/GNN_4_IO/gnn_training200.py
# Out:
# 2024-09-29 22:41:27,427 - INFO - Epoch 1, Train Loss: 1.4126, Train RMSE: 0.4346, Test RMSE: 0.4357, Train MAE: 0.2378, Test MAE: 0.2374, Train R²: -0.2612, Test R²: -0.2601
# 2024-09-29 22:41:39,868 - INFO - Epoch 2, Train Loss: 0.1751, Train RMSE: 0.3754, Test RMSE: 0.3766, Train MAE: 0.1637, Test MAE: 0.1622, Train R²: 0.0588, Test R²: 0.0586
# 2024-09-29 22:41:51,434 - INFO - Epoch 3, Train Loss: 0.1743, Train RMSE: 0.3932, Test RMSE: 0.3942, Train MAE: 0.1524, Test MAE: 0.1516, Train R²: -0.0325, Test R²: -0.0315
# 2024-09-29 22:42:02,951 - INFO - Epoch 4, Train Loss: 0.1689, Train RMSE: 0.4286, Test RMSE: 0.4294, Train MAE: 0.2268, Test MAE: 0.2261, Train R²: -0.2270, Test R²: -0.2238
# 2024-09-29 22:42:14,577 - INFO - Epoch 5, Train Loss: 0.1700, Train RMSE: 0.3924, Test RMSE: 0.3933, Train MAE: 0.1569, Test MAE: 0.1559, Train R²: -0.0282, Test R²: -0.0265
# ...

# %%
# total_rows = 10,000
# Graph200/10,000
# Random selection + Currect Split
# Randomly selected 10000 rows.
# Selected data split into 7500 training rows and 2500 testing rows.
# !source ~/env4/bin/activate && python /u/mbanisharifdehkordi/Github/GNN_4_IO/gnn_training200.py
# Out:
# 2024-09-29 23:07:14,489 - INFO - Epoch 1, Train Loss: 1.7976, Train RMSE: 0.4310, Test RMSE: 0.4456, Train MAE: 0.2289, Test MAE: 0.2332, Train R²: -0.2603, Test R²: -0.2382
# 2024-09-29 23:07:35,139 - INFO - Epoch 2, Train Loss: 0.1776, Train RMSE: 0.3885, Test RMSE: 0.4049, Train MAE: 0.1592, Test MAE: 0.1636, Train R²: -0.0239, Test R²: -0.0226
# ^C
# Graceful termination initiated...
# Traceback (most recent call last):
#   File "/u/mbanisharifdehkordi/Github/GNN_4_IO/gnn_training200.py", line 322, in <module>
#     train_losses, train_rmse_scores, test_rmse_scores, train_mae_scores, test_mae_scores, train_r2_scores, test_r2_scores = train(model, train_loader, test_loader, criterion, optimizer, scheduler, num_epochs, checkpoint_path, update_logs_and_charts)
#   File "/u/mbanisharifdehkordi/Github/GNN_4_IO/gnn_training200.py", line 205, in train
#     loss.backward()
#   File "/u/mbanisharifdehkordi/env4/lib/python3.9/site-packages/torch/_tensor.py", line 521, in backward
# ...

# %%
# total_rows = 40,000
# Graph200/40,000
# Random selection + Currect Split
# !source ~/env4/bin/activate && python /u/mbanisharifdehkordi/Github/GNN_4_IO/generate_graph100.py
# Out:
# 2024-09-29 23:12:20,496 - INFO - Starting data processing.
# 2024-09-29 23:12:20,496 - INFO - Loading graph structure from Graphs/Graph200/graph_structure.yaml
# 2024-09-29 23:12:20,524 - INFO - Graph structure loaded successfully.
# 2024-09-29 23:12:20,524 - INFO - Loading dataset from CSVs/sample_train_total.csv
# 2024-09-29 23:12:47,457 - INFO - Dataset loaded successfully with 6647219 total rows.
# 2024-09-29 23:12:47,457 - INFO - Randomly selecting 40000 rows from the dataset
# 2024-09-29 23:12:47,627 - INFO - Randomly selected 40000 rows.
# 2024-09-29 23:12:47,627 - INFO - Splitting selected data into training and testing sets with test size = 0.25
# 2024-09-29 23:12:47,637 - INFO - Selected data split into 30000 training rows and 10000 testing rows.
# 2024-09-29 23:12:47,637 - INFO - Processing training data with 30000 rows.
# 2024-09-29 23:13:31,369 - INFO - All graphs saved to Graphs/Graph200/40,000/train_graphs.csv.
# ...

# %%
# total_rows = 40,000
# Graph200/40,000
# Random selection + Currect Split
# Randomly selected 40000 rows.
# Selected data split into 30000 training rows and 10000 testing rows.
# !source ~/env4/bin/activate && python /u/mbanisharifdehkordi/Github/GNN_4_IO/gnn_training200.py
# Out:
# 2024-09-29 23:18:46,929 - INFO - Epoch 1, Train Loss: 0.5819, Train RMSE: 0.3956, Test RMSE: 0.3973, Train MAE: 0.1541, Test MAE: 0.1525, Train R²: -0.0881, Test R²: -0.0853
# 2024-09-29 23:19:30,047 - INFO - Epoch 2, Train Loss: 0.1662, Train RMSE: 0.4146, Test RMSE: 0.4160, Train MAE: 0.2019, Test MAE: 0.2005, Train R²: -0.1953, Test R²: -0.1901
# 2024-09-29 23:20:05,205 - INFO - Epoch 3, Train Loss: 0.1632, Train RMSE: 0.3868, Test RMSE: 0.3885, Train MAE: 0.1433, Test MAE: 0.1417, Train R²: -0.0400, Test R²: -0.0376
# 2024-09-29 23:20:41,878 - INFO - Epoch 4, Train Loss: 0.1592, Train RMSE: 0.3775, Test RMSE: 0.3792, Train MAE: 0.1341, Test MAE: 0.1325, Train R²: 0.0094, Test R²: 0.0112
# 2024-09-29 23:21:29,065 - INFO - Epoch 5, Train Loss: 0.1593, Train RMSE: 0.3824, Test RMSE: 0.3840, Train MAE: 0.1487, Test MAE: 0.1471, Train R²: -0.0164, Test R²: -0.0140
# ...

# %%
# total_rows = 10,000
# Graph200/10,000
# Random selection + Currect Split
# Randomly selected 10000 rows.
# Selected data split into 7500 training rows and 2500 testing rows.
# instead of the torch.float -> torch.double
# !source ~/env4/bin/activate && python /u/mbanisharifdehkordi/Github/GNN_4_IO/gnn_training200_double.py
# Out:
# 2024-09-30 01:28:51,596 - INFO - Epoch 1, Train Loss: 1.8146, Train RMSE: 0.4683, Test RMSE: 0.4823, Train MAE: 0.2694, Test MAE: 0.2735, Train R²: -0.4875, Test R²: -0.4507
# 2024-09-30 01:29:06,989 - INFO - Epoch 2, Train Loss: 0.1743, Train RMSE: 0.4395, Test RMSE: 0.4544, Train MAE: 0.2267, Test MAE: 0.2309, Train R²: -0.3104, Test R²: -0.2877
# 2024-09-30 01:29:20,888 - INFO - Epoch 3, Train Loss: 0.1729, Train RMSE: 0.4260, Test RMSE: 0.4412, Train MAE: 0.2040, Test MAE: 0.2081, Train R²: -0.2308, Test R²: -0.2138
# 2024-09-30 01:29:34,366 - INFO - Epoch 4, Train Loss: 0.1696, Train RMSE: 0.4117, Test RMSE: 0.4269, Train MAE: 0.1865, Test MAE: 0.1904, Train R²: -0.1498, Test R²: -0.1365
# 2024-09-30 01:29:47,237 - INFO - Epoch 5, Train Loss: 0.1673, Train RMSE: 0.4063, Test RMSE: 0.4217, Train MAE: 0.1756, Test MAE: 0.1794, Train R²: -0.1201, Test R²: -0.1092
# ...
