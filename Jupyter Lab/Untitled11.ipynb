# %%
# total_rows = 100,000
# !source ~/env4/bin/activate && python /u/mbanisharifdehkordi/Github/GNN_4_IO/nn_dataset101.py
# Out:
# 2024-09-03 04:04:23,577 - INFO - Starting data processing.
# 2024-09-03 04:04:23,577 - INFO - Loading dataset from CSVs/sample_train.csv
# 2024-09-03 04:04:27,474 - INFO - Dataset loaded successfully with 1048575 rows.
# 2024-09-03 04:04:27,533 - INFO - Selected 100000 rows from the dataset.
# 2024-09-03 04:04:27,534 - INFO - Splitting dataset into training and testing sets with test size = 0.25
# 2024-09-03 04:04:27,558 - INFO - Dataset split into 75000 training rows and 25000 testing rows.
# 2024-09-03 04:04:29,233 - INFO - Training data saved to NN/NN_101/train_data.csv.
# 2024-09-03 04:04:29,786 - INFO - Testing data saved to NN/NN_101/test_data.csv.
# 2024-09-03 04:04:29,786 - INFO - Data processing completed.

# %%
# !source ~/env4/bin/activate && python /u/mbanisharifdehkordi/Github/GNN_4_IO/nn_training101.py
# Out:
# 2024-09-03 04:06:43,310 - INFO - Epoch 1, Train Loss: 0.2592, Train RMSE: 0.4291, Test RMSE: 0.4272, Train MAE: 0.3213, Test MAE: 0.3221, Train R²: 0.7133, Test R²: 0.7144
# 2024-09-03 04:06:47,300 - INFO - Epoch 2, Train Loss: 0.1879, Train RMSE: 0.4266, Test RMSE: 0.4248, Train MAE: 0.3195, Test MAE: 0.3208, Train R²: 0.7166, Test R²: 0.7176
# 2024-09-03 04:06:51,275 - INFO - Epoch 3, Train Loss: 0.1708, Train RMSE: 0.3863, Test RMSE: 0.3837, Train MAE: 0.2933, Test MAE: 0.2934, Train R²: 0.7676, Test R²: 0.7696
# 2024-09-03 04:06:55,461 - INFO - Epoch 4, Train Loss: 0.1599, Train RMSE: 0.3515, Test RMSE: 0.3481, Train MAE: 0.2624, Test MAE: 0.2617, Train R²: 0.8076, Test R²: 0.8103
# 2024-09-03 04:06:59,446 - INFO - Epoch 5, Train Loss: 0.1552, Train RMSE: 0.3375, Test RMSE: 0.3336, Train MAE: 0.2535, Test MAE: 0.2523, Train R²: 0.8226, Test R²: 0.8258
# ...

# %%
# !source ~/env4/bin/activate && python /u/mbanisharifdehkordi/Github/GNN_4_IO/nn_training101.py
# Out:
# /u/mbanisharifdehkordi/Github/GNN_4_IO/nn_training101.py:86: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
# total_rows = 6,000,000
# !source ~/env4/bin/activate && python /u/mbanisharifdehkordi/Github/GNN_4_IO/nn_dataset101.py
# Out:
# 2024-09-03 04:17:06,207 - INFO - Starting data processing.
# 2024-09-03 04:17:06,208 - INFO - Loading dataset from CSVs/sample_train.csv
# 2024-09-03 04:17:09,425 - INFO - Dataset loaded successfully with 1048575 rows.
# 2024-09-03 04:17:09,425 - INFO - Processing all 1048575 rows.
# 2024-09-03 04:17:09,425 - INFO - Splitting dataset into training and testing sets with test size = 0.25
# 2024-09-03 04:17:09,655 - INFO - Dataset split into 786431 training rows and 262144 testing rows.
# 2024-09-03 04:17:26,733 - INFO - Training data saved to NN/NN_102/train_data.csv.
# 2024-09-03 04:17:32,417 - INFO - Testing data saved to NN/NN_102/test_data.csv.
# 2024-09-03 04:17:32,418 - INFO - Data processing completed.

# %%
# !source ~/env4/bin/activate && python /u/mbanisharifdehkordi/Github/GNN_4_IO/nn_training101.py
# Out:
# 2024-09-03 04:19:19,417 - INFO - Epoch 1, Train Loss: 0.1678, Train RMSE: 0.3469, Test RMSE: 0.3475, Train MAE: 0.2687, Test MAE: 0.2693, Train R²: 0.8141, Test R²: 0.8127
# 2024-09-03 04:20:03,761 - INFO - Epoch 2, Train Loss: 0.1420, Train RMSE: 0.3363, Test RMSE: 0.3375, Train MAE: 0.2466, Test MAE: 0.2473, Train R²: 0.8253, Test R²: 0.8234
# 2024-09-03 04:20:49,784 - INFO - Epoch 3, Train Loss: 0.1380, Train RMSE: 0.3227, Test RMSE: 0.3237, Train MAE: 0.2441, Test MAE: 0.2447, Train R²: 0.8392, Test R²: 0.8375
# 2024-09-03 04:21:30,504 - INFO - Epoch 4, Train Loss: 0.1360, Train RMSE: 0.3146, Test RMSE: 0.3161, Train MAE: 0.2354, Test MAE: 0.2362, Train R²: 0.8471, Test R²: 0.8450
# 2024-09-03 04:22:12,063 - INFO - Epoch 5, Train Loss: 0.1345, Train RMSE: 0.3185, Test RMSE: 0.3197, Train MAE: 0.2370, Test MAE: 0.2378, Train R²: 0.8433, Test R²: 0.8415
# ...

# %%
# !source ~/env4/bin/activate && python /u/mbanisharifdehkordi/Github/GNN_4_IO/nn_training104.py
# Out:
# 2024-09-03 05:50:54,196 - INFO - Epoch 1, Train Loss: 0.2248, Train RMSE: 0.4360, Test RMSE: 0.4350, Train MAE: 0.3308, Test MAE: 0.3307, Train R²: 0.7064, Test R²: 0.7066
# 2024-09-03 05:51:37,959 - INFO - Epoch 2, Train Loss: 0.1529, Train RMSE: 0.4091, Test RMSE: 0.4088, Train MAE: 0.3071, Test MAE: 0.3071, Train R²: 0.7414, Test R²: 0.7408
# 2024-09-03 05:52:34,984 - INFO - Epoch 3, Train Loss: 0.1382, Train RMSE: 0.4154, Test RMSE: 0.4154, Train MAE: 0.3079, Test MAE: 0.3079, Train R²: 0.7334, Test R²: 0.7324
# 2024-09-03 05:53:32,003 - INFO - Epoch 4, Train Loss: 0.1318, Train RMSE: 0.3893, Test RMSE: 0.3896, Train MAE: 0.2902, Test MAE: 0.2904, Train R²: 0.7658, Test R²: 0.7646
# 2024-09-03 05:54:14,559 - INFO - Epoch 5, Train Loss: 0.1282, Train RMSE: 0.3945, Test RMSE: 0.3949, Train MAE: 0.2893, Test MAE: 0.2896, Train R²: 0.7596, Test R²: 0.7581
# ...
