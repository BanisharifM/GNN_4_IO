# 2024-07-07 04:47:38,241 - INFO - Epoch 6, Train Loss: 3.1892, Val Loss: 8.5325, Train Acc: 0.3211, Val Acc: 0.3513
# 2024-07-07 04:47:56,421 - INFO - Epoch 7, Train Loss: 2.8885, Val Loss: 5.4964, Train Acc: 0.3258, Val Acc: 0.3187
# 2024-07-07 04:48:13,555 - INFO - Epoch 8, Train Loss: 2.4181, Val Loss: 4.1769, Train Acc: 0.3327, Val Acc: 0.2875
# ...

# %%
# !python gnn_training34.py
# Out:
# 2024-07-09 15:41:10,511 - INFO - Epoch 1, Train Loss: 18.5808, Train Acc: 0.2939
# 2024-07-09 15:41:31,417 - INFO - Epoch 2, Train Loss: 1.5914, Train Acc: 0.3247
# 2024-07-09 15:41:52,436 - INFO - Epoch 3, Train Loss: 1.5886, Train Acc: 0.3352
# 2024-07-09 15:42:12,918 - INFO - Epoch 4, Train Loss: 1.5437, Train Acc: 0.3523
# 2024-07-09 15:42:33,315 - INFO - Epoch 5, Train Loss: 1.4704, Train Acc: 0.3705
# 2024-07-09 15:42:54,243 - INFO - Epoch 6, Train Loss: 1.4567, Train Acc: 0.3669
# 2024-07-09 15:43:15,216 - INFO - Epoch 7, Train Loss: 1.3577, Train Acc: 0.3825
# 2024-07-09 15:43:35,799 - INFO - Epoch 8, Train Loss: 1.3699, Train Acc: 0.3891
# 2024-07-09 15:43:56,784 - INFO - Epoch 9, Train Loss: 1.4695, Train Acc: 0.3952
# 2024-07-09 15:44:17,863 - INFO - Epoch 10, Train Loss: 1.3406, Train Acc: 0.3987
# 2024-07-09 15:44:39,028 - INFO - Epoch 11, Train Loss: 1.3496, Train Acc: 0.4011
# 2024-07-09 15:45:00,332 - INFO - Epoch 12, Train Loss: 1.3665, Train Acc: 0.3989
# ...

# %%
# !python generate_graph28.py
# Out:
# 2024-07-22 17:22:37,026 - INFO - Starting data processing.
# 2024-07-22 17:22:37,026 - INFO - Loading graph structure from Graphs/Graph40/graph_structure.yaml
# 2024-07-22 17:22:37,046 - INFO - Graph structure loaded successfully.
# 2024-07-22 17:22:37,046 - INFO - Processing training data from CSVs/train_data.csv with 1000 rows.
# 2024-07-22 17:22:37,071 - INFO - Processing chunk 1 for training data.
# 2024-07-22 17:22:37,915 - INFO - Processed 1000 rows for training data.
# 2024-07-22 17:22:37,915 - INFO - All training graphs saved to Graphs/Graph40/train_graphs.csv.
# 2024-07-22 17:22:37,922 - INFO - Data processing completed.

# %%
# !python gnn_training_test.py
# Out:
# 2024-07-09 23:02:21,953 - INFO - Epoch 1, Train Loss: 138.1717, Train Acc: 0.2770
# 2024-07-09 23:02:23,179 - INFO - Epoch 2, Train Loss: 44.0241, Train Acc: 0.2860
# 2024-07-09 23:02:24,095 - INFO - Epoch 3, Train Loss: 31.1300, Train Acc: 0.2690
# 2024-07-09 23:02:24,912 - INFO - Epoch 4, Train Loss: 8.6594, Train Acc: 0.2890
# 2024-07-09 23:02:25,847 - INFO - Epoch 5, Train Loss: 3.7482, Train Acc: 0.3170
# 2024-07-09 23:02:26,687 - INFO - Epoch 6, Train Loss: 4.9469, Train Acc: 0.2940
# 2024-07-09 23:02:27,483 - INFO - Epoch 7, Train Loss: 3.1964, Train Acc: 0.3160
# 2024-07-09 23:02:28,302 - INFO - Epoch 8, Train Loss: 2.2184, Train Acc: 0.3410
# 2024-07-09 23:02:29,163 - INFO - Epoch 9, Train Loss: 1.9127, Train Acc: 0.3290
# 2024-07-09 23:02:29,969 - INFO - Epoch 10, Train Loss: 2.0992, Train Acc: 0.3130
# 2024-07-09 23:02:30,769 - INFO - Epoch 11, Train Loss: 2.4910, Train Acc: 0.3210
# 2024-07-09 23:02:31,588 - INFO - Epoch 12, Train Loss: 2.1444, Train Acc: 0.3150
# ...

# %%
# !python gnn_training38.py
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1eJXrfEEpPO2warvj0GhbSzU_1eXGq0j1&export=download
# From (redirected): https://drive.google.com/uc?id=1eJXrfEEpPO2warvj0GhbSzU_1eXGq0j1&export=download&confirm=t&uuid=e256c466-2738-4811-a847-7a73da3bb091
# To: /work/LAS/jannesar-lab/Mahdi/Darshan-logs-Processing/Graphs/Graph38/train_graphs.csv
# 100%|████████████████████████████████████████| 245M/245M [00:02<00:00, 94.9MB/s]
# 2024-07-10 04:37:40,690 - INFO - Loading graph structure from Graphs/Graph38/graph_structure.yaml
# 2024-07-10 04:37:42,016 - INFO - DataFrame columns: ['graph_index', 'source', 'target', 'tag_value', 'node_value']
# 2024-07-10 04:39:51,781 - INFO - Resuming from epoch 102
# 2024-07-10 04:40:29,620 - INFO - Epoch 103, Train Loss: 1.3652, Train Acc: 0.3560
# 2024-07-10 04:41:08,822 - INFO - Epoch 104, Train Loss: 1.3651, Train Acc: 0.3562
# 2024-07-10 04:41:47,137 - INFO - Epoch 105, Train Loss: 1.3655, Train Acc: 0.3560
# ...

# %%
# !python generate_graph44.py
# Out:
# 2024-07-22 23:54:53,747 - INFO - Starting data processing.
# 2024-07-22 23:54:53,748 - INFO - Loading graph structure from Graphs/Graph44/graph_structure.yaml
# 2024-07-22 23:54:53,798 - INFO - Graph structure loaded successfully.
# 2024-07-22 23:54:53,798 - INFO - Loading dataset from CSVs/sample_train.csv
# 2024-07-22 23:55:21,235 - INFO - Splitting dataset into training and testing sets with test size = 0.5
# 2024-07-22 23:55:24,530 - INFO - Processing training data with 3323609 rows.
# 2024-07-23 00:03:25,123 - INFO - All graphs saved to Graphs/Graph44/train_graphs.csv.
# 2024-07-23 00:03:29,804 - INFO - Processing testing data with 3323610 rows.
# 2024-07-23 00:11:30,702 - INFO - All graphs saved to Graphs/Graph44/test_graphs.csv.
# 2024-07-23 00:11:35,140 - INFO - Data processing completed.

# %%
# !python gnn_training44.py
# Out:
# ^C
# Traceback (most recent call last):
#   File "/work/LAS/jannesar-lab/Mahdi/Darshan-logs-Processing/gnn_training44.py", line 64, in <module>
#     train_data = load_data(train_file_path)
#   File "/work/LAS/jannesar-lab/Mahdi/Darshan-logs-Processing/gnn_training44.py", line 51, in load_data
#     graph_df = df[df['graph_index'] == graph_index]
#   File "/opt/python310/lib/python3.10/site-packages/pandas/core/ops/common.py", line 81, in new_method
#     return method(self, other)
#   File "/opt/python310/lib/python3.10/site-packages/pandas/core/arraylike.py", line 40, in __eq__
#     return self._cmp_method(other, operator.eq)
#   File "/opt/python310/lib/python3.10/site-packages/pandas/core/series.py", line 6092, in _cmp_method
#     res_values = ops.comparison_op(lvalues, rvalues, op)
#   File "/opt/python310/lib/python3.10/site-packages/pandas/core/ops/array_ops.py", line 296, in comparison_op
#     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
# ...

# %%
# !python generate_graph45.py
# Out:
# 2024-07-23 03:50:52,190 - INFO - Starting data processing.
# 2024-07-23 03:50:52,190 - INFO - Loading graph structure from Graphs/Graph45/graph_structure.yaml
# 2024-07-23 03:50:52,195 - INFO - Graph structure loaded successfully.
# 2024-07-23 03:50:52,195 - INFO - Loading dataset from CSVs/sample_train.csv
# 2024-07-23 03:51:18,585 - INFO - Splitting dataset into training and testing sets with test size = 0.5
# 2024-07-23 03:51:21,221 - INFO - Processing training data with 3323609 rows.
# 2024-07-23 04:09:45,176 - INFO - All graphs saved to Graphs/Graph45/train_graphs.csv.
# 2024-07-23 04:09:56,007 - INFO - Processing testing data with 3323610 rows.
# 2024-07-23 04:28:23,324 - INFO - All graphs saved to Graphs/Graph45/test_graphs.csv.
# 2024-07-23 04:28:34,267 - INFO - Data processing completed.

# %%
!~/env4/bin/python gnn_training54.py
# Out:
# 2024-08-07 03:30:01,314 - INFO - Epoch 1, Train Loss: 0.8473, Train RMSE: 0.8599, Test RMSE: 0.8578, Train MAE: 0.6675, Test MAE: 0.6713, Train R²: 0.2156, Test R²: 0.2137
# 2024-08-07 03:30:04,156 - INFO - Epoch 2, Train Loss: 0.6749, Train RMSE: 0.8621, Test RMSE: 0.8590, Train MAE: 0.6651, Test MAE: 0.6679, Train R²: 0.2117, Test R²: 0.2115
# 2024-08-07 03:30:07,013 - INFO - Epoch 3, Train Loss: 0.6651, Train RMSE: 0.8545, Test RMSE: 0.8512, Train MAE: 0.6579, Test MAE: 0.6598, Train R²: 0.2256, Test R²: 0.2258
# 2024-08-07 03:30:09,893 - INFO - Epoch 4, Train Loss: 0.6570, Train RMSE: 0.8579, Test RMSE: 0.8565, Train MAE: 0.6553, Test MAE: 0.6570, Train R²: 0.2192, Test R²: 0.2161
# 2024-08-07 03:30:12,751 - INFO - Epoch 5, Train Loss: 0.6550, Train RMSE: 0.8448, Test RMSE: 0.8415, Train MAE: 0.6470, Test MAE: 0.6482, Train R²: 0.2430, Test R²: 0.2434
# ...

# %%
!~/env4/bin/python gnn_training55.py
# Out:
# 2024-08-07 06:13:05,607 - INFO - Epoch 1, Train Loss: 0.8459, Train RMSE: 0.8574, Test RMSE: 0.8558, Train MAE: 0.6654, Test MAE: 0.6691, Train R²: 0.2203, Test R²: 0.2175
# 2024-08-07 06:13:08,488 - INFO - Epoch 2, Train Loss: 0.6737, Train RMSE: 0.8552, Test RMSE: 0.8524, Train MAE: 0.6632, Test MAE: 0.6669, Train R²: 0.2242, Test R²: 0.2236
# 2024-08-07 06:13:11,279 - INFO - Epoch 3, Train Loss: 0.6660, Train RMSE: 0.8674, Test RMSE: 0.8670, Train MAE: 0.6696, Test MAE: 0.6721, Train R²: 0.2020, Test R²: 0.1968
# 2024-08-07 06:13:14,077 - INFO - Epoch 4, Train Loss: 0.6635, Train RMSE: 0.8631, Test RMSE: 0.8626, Train MAE: 0.6669, Test MAE: 0.6683, Train R²: 0.2099, Test R²: 0.2048
# 2024-08-07 06:13:16,827 - INFO - Epoch 5, Train Loss: 0.6572, Train RMSE: 0.8402, Test RMSE: 0.8380, Train MAE: 0.6461, Test MAE: 0.6485, Train R²: 0.2513, Test R²: 0.2496
# ...
