# %%
# total_rows = 10
# Graph201/10
# Node name mapping
# !source ~/env4/bin/activate && python /u/mbanisharifdehkordi/Github/GNN_4_IO/generate_graph201.py
# Out:
# 2024-10-03 21:54:10,135 - INFO - Starting data processing.
# 2024-10-03 21:54:10,135 - INFO - Loading graph structure from Graphs/Graph201/graph_structure.yaml
# 2024-10-03 21:54:10,163 - INFO - Graph structure loaded successfully.
# 2024-10-03 21:54:10,163 - INFO - Loading counter to integer mapping from Graphs/Graph201/counter_2_int.yml
# 2024-10-03 21:54:10,167 - INFO - Counter to integer mapping loaded successfully.
# 2024-10-03 21:54:10,167 - INFO - Loading dataset from CSVs/sample_train_100.csv
# 2024-10-03 21:54:10,170 - INFO - Dataset loaded successfully with 100 total rows.
# 2024-10-03 21:54:10,170 - INFO - Randomly selecting 10 rows from the dataset
# 2024-10-03 21:54:10,170 - INFO - Randomly selected 10 rows.
# 2024-10-03 21:54:10,170 - INFO - Splitting selected data into training and testing sets with test size = 0.25
# 2024-10-03 21:54:10,171 - INFO - Selected data split into 7 training rows and 3 testing rows.
# ...
